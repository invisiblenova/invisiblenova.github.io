# %%
import pandas as pd

# 读取Excel表格
df = pd.read_excel('../data.xlsx',usecols="J")
df.to_csv('../data.txt', header=None, sep=' ', index=False)

# 获取第一列的所有单元格数据，将其存储到一个列表中

# column_data = df['J'].tolist()

# 将数据保存到文本文件中
#with open('data.txt', 'w') as f:
#    f.write('\n'.join(map(str, column_data)))

# %%
df
# Out:
#        患者性别岁数                                             标题链接  \
# 0      男  66岁  https://www.haodf.com/bingcheng/8890788686.html
# 1      女  74岁  https://www.haodf.com/bingcheng/8890780541.html
# 2      男  67岁  https://www.haodf.com/bingcheng/8890775913.html
# 3      男  56岁  https://www.haodf.com/bingcheng/8890775407.html
# 4      女  53岁  https://www.haodf.com/bingcheng/8890773653.html
# ...       ...                                              ...
# 10578  男  53岁  https://www.haodf.com/bingcheng/8880725315.html
# 10579  女  35岁  https://www.haodf.com/bingcheng/8880725163.html
# 10580  女  73岁  https://www.haodf.com/bingcheng/8880724559.html
# 10581  男  66岁  https://www.haodf.com/bingcheng/8880723398.html
# 10582  女  42岁  https://www.haodf.com/bingcheng/8880722822.html
#
#                       病历概况 doctor-info 医生姓名     hospital              date  \
# 0                   确诊胃癌3周     总交流次数 2   彭智     北京大学肿瘤医院       最后交流时间03.12
# ...
